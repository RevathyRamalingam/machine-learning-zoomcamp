# %% [markdown]
# <a href="https://colab.research.google.com/github/RevathyRamalingam/machine-learning-zoomcamp/blob/master/TensorFlowPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
tf.version
# Out:
# <module 'tensorflow._api.v2.version' from '/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/version/__init__.py'>
